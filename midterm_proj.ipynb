# %%
'''
#Train a simple deep CNN on the CIFAR100 small images dataset.
It gets to 75% validation accuracy in 25 epochs, and 79% after 50 epochs.
(it's still underfitting at that point, though).
'''
from __future__ import print_function
import keras
from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
import matplotlib.pyplot as plt
from keras.optimizers import SGD

# %%
batch_size = 512
num_classes = 100
epochs = 50
data_augmentation = False
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar100_trained_model.h5'
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
def cnn_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), padding='same',
      input_shape=x_train.shape[1:]))
  model.add(Activation('relu'))
  model.add(Conv2D(32, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))


  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(128, (3, 3), padding='same'))
  model.add(Activation('relu'))
  model.add(Conv2D(128, (3, 3)))
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))

  # initiate RMSprop optimizer
  opt = keras.optimizers.legacy.RMSprop(learning_rate=0.001, decay=1e-6)
  model.compile(loss='categorical_crossentropy',
  optimizer=opt,
  metrics=['accuracy'])

  return model

# %%
cifar_model = cnn_model()

# Let's train the model using RMSprop
cifar_history = None
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
if not data_augmentation:
  print('Not using data augmentation.')
  cifar_history = cifar_model.fit(x_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      validation_data=(x_test, y_test),
      shuffle=True)
else:
  print('Using real-time data augmentation.')
  # This will do preprocessing and realtime data augmentation:
  datagen = ImageDataGenerator(
    featurewise_center=False, # set input mean to 0 over the dataset
    samplewise_center=False, # set each sample mean to 0
    featurewise_std_normalization=False, # divide inputs by std of the dataset
    samplewise_std_normalization=False, # divide each input by its std
    zca_whitening=False, # apply ZCA whitening
    zca_epsilon=1e-06, # epsilon for ZCA whitening
    rotation_range=0, # randomly rotate images in the range (degrees, 0 to 180)
    # randomly shift images horizontally (fraction of total width)
    width_shift_range=0.1,
    # randomly shift images vertically (fraction of total height)
    height_shift_range=0.1,
    shear_range=0., # set range for random shear
    zoom_range=0., # set range for random zoom
    channel_shift_range=0., # set range for random channel shifts
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    cval=0., # value used for fill_mode = "constant"
    horizontal_flip=True, # randomly flip images
    vertical_flip=False, # randomly flip images
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)
  # Compute quantities required for feature-wise normalization
  # (std, mean, and principal components if ZCA whitening is applied).
  datagen.fit(x_train)

  # Fit the model on the batches generated by datagen.flow().
  cifar_history = cifar_model.fit_generator(datagen.flow(x_train, y_train,
                  batch_size=batch_size),
            epochs=epochs,
            validation_data=(x_test, y_test),
            workers=4)
# Out:
# Not using data augmentation.
# Epoch 1/50
# 98/98 [==============================] - 7s 51ms/step - loss: 4.5178 - accuracy: 0.0201 - val_loss: 4.4511 - val_accuracy: 0.0426
# Epoch 2/50
# 98/98 [==============================] - 4s 44ms/step - loss: 4.2232 - accuracy: 0.0478 - val_loss: 4.0320 - val_accuracy: 0.0774
# Epoch 3/50
# 98/98 [==============================] - 4s 43ms/step - loss: 3.9951 - accuracy: 0.0837 - val_loss: 3.7965 - val_accuracy: 0.1213
# Epoch 4/50
# 98/98 [==============================] - 4s 45ms/step - loss: 3.8032 - accuracy: 0.1161 - val_loss: 3.7456 - val_accuracy: 0.1342
# Epoch 5/50
# 98/98 [==============================] - 4s 44ms/step - loss: 3.6565 - accuracy: 0.1382 - val_loss: 3.5893 - val_accuracy: 0.1522
# Epoch 6/50
# 98/98 [==============================] - 4s 44ms/step - loss: 3.5325 - accuracy: 0.1608 - val_loss: 3.3695 - val_accuracy: 0.2035
# Epoch 7/50
# 98/98 [==============================] - 4s 44ms/step - loss: 3.4254 - accuracy: 0.1788 - val_loss: 3.2744 - val_accuracy: 0.2128
# Epoch 8/50
# 98/98 [==============================] - 4s 45ms/step - loss: 3.3289 - accuracy: 0.1981 - val_loss: 3.3754 - val_accuracy: 0.1892
# Epoch 9/50
# 98/98 [==============================] - 4s 44ms/step - loss: 3.2439 - accuracy: 0.2126 - val_loss: 3.0889 - val_accuracy: 0.2469
# Epoch 10/50
# 98/98 [==============================] - 4s 44ms/step - loss: 3.1657 - accuracy: 0.2266 - val_loss: 3.0054 - val_accuracy: 0.2648
# Epoch 11/50
# 98/98 [==============================] - 4s 44ms/step - loss: 3.0874 - accuracy: 0.2423 - val_loss: 2.9977 - val_accuracy: 0.2666
# Epoch 12/50
# 98/98 [==============================] - 4s 46ms/step - loss: 3.0073 - accuracy: 0.2557 - val_loss: 2.9394 - val_accuracy: 0.2765
# Epoch 13/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.9492 - accuracy: 0.2663 - val_loss: 2.9440 - val_accuracy: 0.2788
# Epoch 14/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.8780 - accuracy: 0.2819 - val_loss: 2.7139 - val_accuracy: 0.3229
# Epoch 15/50
# 98/98 [==============================] - 5s 46ms/step - loss: 2.8299 - accuracy: 0.2906 - val_loss: 2.7182 - val_accuracy: 0.3200
# Epoch 16/50
# 98/98 [==============================] - 4s 44ms/step - loss: 2.7777 - accuracy: 0.2994 - val_loss: 2.7483 - val_accuracy: 0.3223
# Epoch 17/50
# 98/98 [==============================] - 4s 44ms/step - loss: 2.7298 - accuracy: 0.3109 - val_loss: 2.6765 - val_accuracy: 0.3297
# Epoch 18/50
# 98/98 [==============================] - 5s 46ms/step - loss: 2.6662 - accuracy: 0.3242 - val_loss: 2.6383 - val_accuracy: 0.3383
# Epoch 19/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.6224 - accuracy: 0.3329 - val_loss: 2.5418 - val_accuracy: 0.3566
# Epoch 20/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.5769 - accuracy: 0.3417 - val_loss: 2.4855 - val_accuracy: 0.3627
# Epoch 21/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.5225 - accuracy: 0.3529 - val_loss: 2.4730 - val_accuracy: 0.3718
# Epoch 22/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.4855 - accuracy: 0.3581 - val_loss: 2.3931 - val_accuracy: 0.3850
# Epoch 23/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.4439 - accuracy: 0.3686 - val_loss: 2.4219 - val_accuracy: 0.3871
# Epoch 24/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.4153 - accuracy: 0.3756 - val_loss: 2.4319 - val_accuracy: 0.3759
# Epoch 25/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.3813 - accuracy: 0.3819 - val_loss: 2.2973 - val_accuracy: 0.4103
# Epoch 26/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.3413 - accuracy: 0.3896 - val_loss: 2.2894 - val_accuracy: 0.4101
# Epoch 27/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.3060 - accuracy: 0.3968 - val_loss: 2.3491 - val_accuracy: 0.3989
# Epoch 28/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.2781 - accuracy: 0.4009 - val_loss: 2.2628 - val_accuracy: 0.4164
# Epoch 29/50
# 98/98 [==============================] - 5s 46ms/step - loss: 2.2431 - accuracy: 0.4087 - val_loss: 2.2190 - val_accuracy: 0.4253
# Epoch 30/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.2118 - accuracy: 0.4177 - val_loss: 2.3526 - val_accuracy: 0.4011
# Epoch 31/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.1838 - accuracy: 0.4217 - val_loss: 2.1805 - val_accuracy: 0.4340
# Epoch 32/50
# 98/98 [==============================] - 5s 46ms/step - loss: 2.1515 - accuracy: 0.4301 - val_loss: 2.1569 - val_accuracy: 0.4383
# Epoch 33/50
# 98/98 [==============================] - 4s 44ms/step - loss: 2.1348 - accuracy: 0.4324 - val_loss: 2.2136 - val_accuracy: 0.4321
# Epoch 34/50
# 98/98 [==============================] - 5s 46ms/step - loss: 2.0968 - accuracy: 0.4413 - val_loss: 2.1760 - val_accuracy: 0.4379
# Epoch 35/50
# 98/98 [==============================] - 4s 45ms/step - loss: 2.0844 - accuracy: 0.4423 - val_loss: 2.1465 - val_accuracy: 0.4458
# Epoch 36/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.0526 - accuracy: 0.4497 - val_loss: 2.1087 - val_accuracy: 0.4509
# Epoch 37/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.0284 - accuracy: 0.4550 - val_loss: 2.2010 - val_accuracy: 0.4341
# Epoch 38/50
# 98/98 [==============================] - 4s 46ms/step - loss: 2.0100 - accuracy: 0.4590 - val_loss: 2.1463 - val_accuracy: 0.4448
# Epoch 39/50
# 98/98 [==============================] - 4s 45ms/step - loss: 1.9849 - accuracy: 0.4649 - val_loss: 2.1414 - val_accuracy: 0.4475
# Epoch 40/50
# 98/98 [==============================] - 4s 46ms/step - loss: 1.9660 - accuracy: 0.4672 - val_loss: 2.1043 - val_accuracy: 0.4538
# Epoch 41/50
# 98/98 [==============================] - 4s 45ms/step - loss: 1.9446 - accuracy: 0.4708 - val_loss: 2.0688 - val_accuracy: 0.4620
# Epoch 42/50
# 98/98 [==============================] - 4s 45ms/step - loss: 1.9319 - accuracy: 0.4780 - val_loss: 2.0666 - val_accuracy: 0.4601
# Epoch 43/50
# 98/98 [==============================] - 4s 45ms/step - loss: 1.8987 - accuracy: 0.4841 - val_loss: 2.1542 - val_accuracy: 0.4430
# Epoch 44/50
# 98/98 [==============================] - 5s 46ms/step - loss: 1.8909 - accuracy: 0.4863 - val_loss: 2.0805 - val_accuracy: 0.4659
# Epoch 45/50
# 98/98 [==============================] - 5s 46ms/step - loss: 1.8696 - accuracy: 0.4866 - val_loss: 2.0582 - val_accuracy: 0.4658
# Epoch 46/50
# 98/98 [==============================] - 4s 46ms/step - loss: 1.8683 - accuracy: 0.4872 - val_loss: 2.1071 - val_accuracy: 0.4556
# Epoch 47/50
# 98/98 [==============================] - 4s 46ms/step - loss: 1.8398 - accuracy: 0.4978 - val_loss: 2.1782 - val_accuracy: 0.4487
# Epoch 48/50
# 98/98 [==============================] - 5s 47ms/step - loss: 1.8291 - accuracy: 0.4982 - val_loss: 2.0321 - val_accuracy: 0.4740
# Epoch 49/50
# 98/98 [==============================] - 4s 46ms/step - loss: 1.8179 - accuracy: 0.5014 - val_loss: 2.0256 - val_accuracy: 0.4763
# Epoch 50/50
# 98/98 [==============================] - 4s 46ms/step - loss: 1.8043 - accuracy: 0.5045 - val_loss: 2.0838 - val_accuracy: 0.4650

# %%
def plotmodelhistory(history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(cifar_history.history['accuracy'])
    axs[0].plot(cifar_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(cifar_history.history['loss'])
    axs[1].plot(cifar_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

plotmodelhistory(cifar_history)
